# %%
install.packages("tidyverse")
# Out:
# Installing package into 'C:/Users/风雨未留痕/Documents/R/win-library/4.0'
# (as 'lib' is unspecified)
#
# also installing the dependencies 'tinytex', 'blob', 'DBI', 'rmarkdown', 'selectr', 'dbplyr', 'lubridate', 'modelr', 'reprex', 'rvest'
# package 'tinytex' successfully unpacked and MD5 sums checked
# package 'blob' successfully unpacked and MD5 sums checked
# package 'DBI' successfully unpacked and MD5 sums checked
# package 'rmarkdown' successfully unpacked and MD5 sums checked
# package 'selectr' successfully unpacked and MD5 sums checked
# package 'dbplyr' successfully unpacked and MD5 sums checked
# package 'lubridate' successfully unpacked and MD5 sums checked
# package 'modelr' successfully unpacked and MD5 sums checked
# package 'reprex' successfully unpacked and MD5 sums checked
# package 'rvest' successfully unpacked and MD5 sums checked
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# ...

# %%
library(tidyverse)
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.0 --
#
# √ ggplot2 3.3.3     √ purrr   0.3.4
# √ tibble  3.1.0     √ dplyr   1.0.4
# √ tidyr   1.1.2     √ stringr 1.4.0
# √ readr   1.4.0     √ forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter()  masks stats::filter()
# x purrr::flatten() masks jsonlite::flatten()
# x dplyr::lag()     masks stats::lag()

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
ggplot(data = mpg)+geom_point(mapping = aes(x = displ,y=hwy))
# Out:
# plot without title

# %%
ggplot(data = mpg)
# Out:
# plot without title

# %%
nrow(mpg)
# Out:
# [1] 234

# %%
ncol(mpg)
# Out:
# [1] 11

# %%
glimpse(mpg)
# Out:
# Rows: 234
# Columns: 11
# $ manufacturer <chr> "audi", "audi", "audi", "audi", "audi", "audi", "audi", "~
# $ model        <chr> "a4", "a4", "a4", "a4", "a4", "a4", "a4", "a4 quattro", "~
# $ displ        <dbl> 1.8, 1.8, 2.0, 2.0, 2.8, 2.8, 3.1, 1.8, 1.8, 2.0, 2.0, 2.~
# $ year         <int> 1999, 1999, 2008, 2008, 1999, 1999, 2008, 1999, 1999, 200~
# $ cyl          <int> 4, 4, 4, 4, 6, 6, 6, 4, 4, 4, 4, 6, 6, 6, 6, 6, 6, 8, 8, ~
# $ trans        <chr> "auto(l5)", "manual(m5)", "manual(m6)", "auto(av)", "auto~
# $ drv          <chr> "f", "f", "f", "f", "f", "f", "f", "4", "4", "4", "4", "4~
# $ cty          <int> 18, 21, 20, 21, 16, 18, 18, 18, 16, 20, 19, 15, 17, 17, 1~
# $ hwy          <int> 29, 29, 31, 30, 26, 26, 27, 26, 25, 28, 27, 25, 25, 25, 2~
# $ fl           <chr> "p", "p", "p", "p", "p", "p", "p", "p", "p", "p", "p", "p~
# $ class        <chr> "compact", "compact", "compact", "compact", "compact", "c~

# %%
?mpg

# %%
ggplot(mpg)+geom_point(mapping = (aes(x=cyl,y=hwy)))
# Out:
# plot without title

# %%
ggplot(mpg,aes(x=class,y=drv))+geom_point()
# Out:
# plot without title

# %%
ggplot(mpg,aes(x=class,y=drv))+geom_count()
# Out:
# plot without title

# %%
ggplot(data=mpg)+geom_point(mapping=aes(x=displ,y=hwy,color=class))
# Out:
# plot without title

# %%
ggplot(mpg,aes(x=displ,y=hwy,size=class))+geom_point()
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# plot without title

# %%
ggplot(mpg,aes(x = displ, y = hwy, alpha = class))+geom_point()
# Out:
# Warning message:
# "Using alpha for a discrete variable is not advised."
# plot without title

# %%
ggplot(mpg,aes(x = displ, y = hwy, shape = class))+geom_point()
# Out:
# Warning message:
# "The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them."
# Warning message:
# "Removed 62 rows containing missing values (geom_point)."
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %%
ggplot(mpg,aes(x=displ,y=hwy),color="blue")+geom_point()
# Out:
# plot without title

# %%
ggplot(mpg,aes(x=displ,y=hwy),)+geom_point(color="blue")
# Out:
# plot without title

# %%
ggplot(mpg,aes(x=displ,y=hwy,color=cty))+geom_point()
# Out:
# plot without title

# %%
ggplot(mpg,aes(x=displ,y=hwy,size=cty))+geom_point()
# Out:
# plot without title

# %%
ggplot(mpg,aes(x=displ,y=hwy,alpha=cty))+geom_point()
# Out:
# plot without title

# %%
?geom_point

# %%
ggplot(data =mpg,mapping = aes(x=cty,y=hwy))+geom_point(shape=21,colour="black",fill="white",size=5,stock=5)
# Out:
# Warning message:
# "Ignoring unknown parameters: stock"
# plot without title

# %%
ggplot(data=mpg,aes(cty,hwy,colour=displ<5))+geom_point()
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %%
ggplot(mpg)+
    geom_point(mapping=aes(x=displ,y=hwy))+
    facet_grid(drv~cyl)
# Out:
# plot without title

# %%
ggplot(mpg)+
    geom_point(mapping=aes(x=displ,y=hwy))+
    facet_grid(.~cty)
# Out:
# plot without title

# %%
ggplot(mpg)+
    geom_point(mapping = aes(hwy,cty))+
    facet_grid(drv~cyl)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = drv, y = cyl))
# Out:
# plot without title

# %%
ggplot(mpg)+
    geom_point(mapping = aes(displ,hwy))+
    facet_grid(drv~.)
# Out:
# plot without title

# %%
ggplot(mpg)+
    geom_point(mapping = aes(displ,hwy))+
    facet_grid(.~drv)
# Out:
# plot without title

# %%
ggplot(mpg)+
    geom_point(mapping = aes(displ,hwy))+
    facet_wrap(~drv)
# Out:
# plot without title

# %%
ggplot(mpg)+
    geom_point(mapping = aes(displ,hwy))+
    facet_wrap(~class)
# Out:
# plot without title

# %%
ggplot(mpg)+
    geom_point(mapping = aes(displ,hwy))
# Out:
# plot without title

# %%
ggplot(mpg)+
    geom_smooth(mapping = aes(displ,hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(mpg)+
    geom_smooth(mapping = aes(displ,hwy,linetype=drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
  geom_smooth(mapping = aes(x = displ, y = hwy))
              
ggplot(data = mpg) +
  geom_smooth(mapping = aes(x = displ, y = hwy, group = drv))
    
ggplot(data = mpg) +
  geom_smooth(
    mapping = aes(x = displ, y = hwy, color = drv),
    show.legend = FALSE
  )
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
ggplot(mpg)+
    geom_point(mapping = aes(displ,hwy,group=drv))+
    geom_smooth(mapping = aes(displ,hwy,group=drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(displ,hwy)) + 
  geom_point() + 
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x=displ,y=hwy)) + 
  geom_point(mapping=aes(colour=class)) + 
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x=displ,y=hwy)) + 
  geom_point(mapping=aes(colour=class)) + 
  geom_smooth(data=filter(mpg,class=="subcompact"),se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) + 
  geom_point() + 
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
  geom_smooth(
    mapping = aes(x = displ, y = hwy, colour = drv),

  )
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point() +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point(mapping=aes(group=drv),se=FALSE) +
  geom_smooth(se = FALSE)
# Out:
# Warning message:
# "Ignoring unknown parameters: se"
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy,color=drv)) +
  geom_point() +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point(aes(colour=drv)) +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point(aes(colour=drv)) +
  geom_smooth(aes(linetype=drv),se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point(aes(colour=drv))
# Out:
# plot without title
